# %% [markdown]
# Counting Sort

# %%
from random import randint

V = [randint(0, 14) for _ in range(14)]
n = len(V)
print(f"Lista original: {V}")

big = 0
for num in V:
    if num >= big:
        big = num + 1
count = [0 for x in range(big)]

for i, _ in enumerate(count):
    c = 0
    for value in V:
        if i == value:
            c += 1
    count[i] = c


V_sorted = [0 for x in range(n)]
c = 0
for i, value in enumerate(count):
    if value > 0:
        for _ in range(value):
            V_sorted[c] = i
            c += 1

print(f"Lista ordenada: {V_sorted}")
# Out:
# Lista original: [6, 3, 11, 6, 1, 5, 12, 11, 11, 9, 3, 14, 10, 9]
# Lista ordenada: [1, 3, 3, 5, 6, 6, 9, 9, 10, 11, 11, 11, 12, 14]
